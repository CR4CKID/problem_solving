# %%
from Bio import SeqIO
from Bio.motifs import Motif
from Bio import motifs
from Bio import AlignIO
from Bio.Align.Applications import MuscleCommandline
from IPython.display import Image

# %%
cd4s = [c.seq[:10] for c in SeqIO.parse('cd4.fasta', 'fasta')]
cd4s[:1000]
# Out:
# [Seq('GCTGGCTTCC'),
#  Seq('GCGTGGAGGA'),
#  Seq('CTCTCTTCAT'),
#  Seq('CTCTCTTCAT'),
#  Seq('CTCTCTTCAT'),
#  Seq('ATGCCTGGGG'),
#  Seq('TGCCGGGCTT'),
#  Seq('ATGCACCGAG'),
#  Seq('CTTCCTGTCT'),
#  Seq('TTGGCCCAGG'),
#  Seq('GGTTGGCCCA'),
#  Seq('GGCAGGGACT'),
#  Seq('CTAGCCTGAG'),
#  Seq('GACTCGCTAC'),
#  Seq('GACTCGCTAC'),
#  Seq('GACTCGCTAC'),
#  Seq('CTCTCCCCAG'),
#  Seq('TTTTCATAAC'),
#  Seq('AACTCCGTCT'),
#  Seq('CGGAGGGTGG'),
#  Seq('ATAACTCCGT'),
#  Seq('ATAACTCCGT'),
#  Seq('TAACTCCGTC'),
#  Seq('CCTTCGTGCG'),
#  Seq('CAGCGTTTCC'),
#  Seq('CAGCATTTCC'),
#  Seq('CCTATTAGGA'),
#  Seq('AGGATGGGGG'),
#  Seq('TACCTTCCGT'),
#  Seq('CATTTCCCTC'),
#  Seq('ATGAGAAATG'),
#  Seq('AAGTCACGGC'),
#  Seq('CGAACATCTG'),
#  Seq('AAGCGTATCT'),
#  Seq('AAGCGTATCT'),
#  Seq('TTGGAAAATC'),
#  Seq('CCTGCCGAGA'),
#  Seq('ATACATCTCT'),
#  Seq('ATACATCTCT'),
#  Seq('CCGCTCAGGT'),
#  Seq('CGGGCATCTG'),
#  Seq('ATGGAGTCGA'),
#  Seq('ATGGAGTTGA'),
#  Seq('TACTAGGCTT'),
#  Seq('ACTCCAGAGG'),
# ...

# %%
m = motifs.create(cd4s)

# %%
Motif.weblogo(m, 'cd4.png', fmt='png_print')
Image('cd4.png')

# %%
cd4_one = [cd.seq[:10] for cd in SeqIO.parse('CD4_refseq_transcript.fasta', 'fasta')]

m = motifs.create(cd4_one)

Motif.weblogo(m, 'cd4.png', fmt='png_print')
Image('cd4.png')
